# %%
import pandas as pd
import urllib
import matplotlib.pyplot as plt
import numpy as np
import cv2
import glob
import os
import time
from PIL import Image

from keras.applications.vgg16 import VGG16
from keras.layers import Flatten, Dense, Conv2D, MaxPooling2D, Input, Dropout
from keras.models import Model, Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam

# %%
df = pd.read_json("Indian_Number_plates.json", lines=True)

# %%
dataset = dict()
dataset["image_name"] = list()
dataset["image_width"] = list()
dataset["image_height"] = list()
dataset["top_x"] = list()
dataset["top_y"] = list()
dataset["bottom_x"] = list()
dataset["bottom_y"] = list()

counter = 0
for index, row in df.iterrows():
    img = urllib.request.urlopen(row["content"])
    img = Image.open(img)
    img = img.convert('RGB')
    img.save("licensed_car{}.jpeg".format(counter), "JPEG")
    
    dataset["image_name"].append("licensed_car{}".format(counter))
    
    data = row["annotation"]
    
    dataset["image_width"].append(data[0]["imageWidth"])
    dataset["image_height"].append(data[0]["imageHeight"])
    dataset["top_x"].append(data[0]["points"][0]["x"])
    dataset["top_y"].append(data[0]["points"][0]["y"])
    dataset["bottom_x"].append(data[0]["points"][1]["x"])
    dataset["bottom_y"].append(data[0]["points"][1]["y"])
    
    counter += 1
print("Downloaded {} car images.".format(counter))
# Out:
# Downloaded 237 car images.

# %%
df = pd.DataFrame(dataset)
df.to_csv("indian_license_plates.csv", index=False)
df = pd.read_csv("indian_license_plates.csv")
df["image_name"] = df["image_name"] + ".jpeg"
df.drop(["image_width", "image_height"], axis=1, inplace=True)
df.head()
# Out:
#            image_name     top_x     top_y  bottom_x  bottom_y
# 0  licensed_car0.jpeg  0.722084  0.587983  0.868486  0.688841
# 1  licensed_car1.jpeg  0.161943  0.850780  0.582996  1.000000
# 2  licensed_car2.jpeg  0.082000  0.697452  0.230000  0.828025
# 3  licensed_car3.jpeg  0.434000  0.667377  0.718000  0.765458
# 4  licensed_car4.jpeg  0.208791  0.390764  0.865135  0.984014

# %%
lucky_test_samples = np.random.randint(0, len(df), 5)

# %%
lucky_test_samples = np.random.randint(0, len(df), 5)
reduced_df = df.drop(lucky_test_samples, axis=0)

WIDTH = 224
HEIGHT = 224
CHANNEL = 3

def show_img(index):
    image = cv2.imread(df["image_name"].iloc[index])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, dsize=(WIDTH, HEIGHT))

    tx = int(df["top_x"].iloc[index] * WIDTH)
    ty = int(df["top_y"].iloc[index] * HEIGHT)
    bx = int(df["bottom_x"].iloc[index] * WIDTH)
    by = int(df["bottom_y"].iloc[index] * HEIGHT)

    image = cv2.rectangle(image, (tx, ty), (bx, by), (0, 0, 255), 1)

# %%
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.1)

train_generator = datagen.flow_from_dataframe(
    reduced_df,
    #directory="Indian Number Plates/",
    x_col="image_name",
    y_col=["top_x", "top_y", "bottom_x", "bottom_y"],
    target_size=(WIDTH, HEIGHT),
    batch_size=32, 
    class_mode="other",
    subset="training")

validation_generator = datagen.flow_from_dataframe(
    reduced_df,
    #directory="Indian Number Plates/",
    x_col="image_name",
    y_col=["top_x", "top_y", "bottom_x", "bottom_y"],
    target_size=(WIDTH, HEIGHT),
    batch_size=32, 
    class_mode="other",
    subset="validation")
# Out:
# Found 209 validated image filenames.
# Found 23 validated image filenames.
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\logging\__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\logging\__init__.py", line 840, in format
#     return fmt.format(record)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\logging\__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\logging\__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\asyncio\base_events.py", line 442, in run_forever
#     self._run_once()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\asyncio\base_events.py", line 1462, in _run_once
#     handle._run()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel\kernelbase.py", line 362, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel\kernelbase.py", line 265, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel\kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\IPython\core\interactiveshell.py", line 2867, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\IPython\core\interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-27-43350576bf23>", line 11, in <module>
#     subset="training")
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tensorflow\python\keras\preprocessing\image.py", line 1072, in flow_from_dataframe
#     '`class_mode` "raw".', DeprecationWarning)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tensorflow\python\platform\tf_logging.py", line 173, in warn
#     get_logger().warning(msg, *args, **kwargs)
# Message: '`class_mode` "other" is deprecated, please use `class_mode` "raw".'
# Arguments: (<class 'DeprecationWarning'>,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\logging\__init__.py", line 994, in emit
#     msg = self.format(record)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\logging\__init__.py", line 840, in format
#     return fmt.format(record)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\logging\__init__.py", line 577, in format
#     record.message = record.getMessage()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\logging\__init__.py", line 338, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\asyncio\base_events.py", line 442, in run_forever
#     self._run_once()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\asyncio\base_events.py", line 1462, in _run_once
#     handle._run()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel\kernelbase.py", line 362, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel\kernelbase.py", line 265, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel\kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tornado\gen.py", line 162, in _fake_ctx_run
#     return f(*args, **kw)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel\ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\ipykernel\zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\IPython\core\interactiveshell.py", line 2867, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\IPython\core\interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-27-43350576bf23>", line 21, in <module>
#     subset="validation")
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tensorflow\python\keras\preprocessing\image.py", line 1072, in flow_from_dataframe
#     '`class_mode` "raw".', DeprecationWarning)
#   File "c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tensorflow\python\platform\tf_logging.py", line 173, in warn
#     get_logger().warning(msg, *args, **kwargs)
# Message: '`class_mode` "other" is deprecated, please use `class_mode` "raw".'
# Arguments: (<class 'DeprecationWarning'>,)

# %%
model = Sequential()
model.add(VGG16(weights="imagenet", include_top=False, input_shape=(HEIGHT, WIDTH, CHANNEL)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(4, activation="sigmoid"))
model.layers[-6].trainable = False
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 7s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3211392
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 17,938,756
# Trainable params: 3,224,068
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
STEP_SIZE_TRAIN = int(np.ceil(train_generator.n / train_generator.batch_size))
STEP_SIZE_VAL = int(np.ceil(validation_generator.n / validation_generator.batch_size))

print("Train step size:", STEP_SIZE_TRAIN)
print("Validation step size:", STEP_SIZE_VAL)

train_generator.reset()
validation_generator.reset()
# Out:
# Train step size: 7
# Validation step size: 1

# %%
adam = Adam(lr=0.0005)
model.compile(optimizer=adam, loss="mse")
history = model.fit_generator(train_generator,
    steps_per_epoch=STEP_SIZE_TRAIN,
    validation_data=validation_generator,
    validation_steps=STEP_SIZE_VAL,
    epochs=30)
# Out:
# c:\users\91974\anaconda3\envs\number_plate\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 7/7 [==============================] - 59s 8s/step - loss: 0.0573 - val_loss: 0.0208
# Epoch 2/30
# 7/7 [==============================] - 62s 9s/step - loss: 0.0163 - val_loss: 0.0182
# Epoch 3/30
# 7/7 [==============================] - 61s 9s/step - loss: 0.0076 - val_loss: 0.0155
# Epoch 4/30
# 7/7 [==============================] - 62s 9s/step - loss: 0.0047 - val_loss: 0.0135
# Epoch 5/30
# 7/7 [==============================] - 62s 9s/step - loss: 0.0027 - val_loss: 0.0129
# Epoch 6/30
# 7/7 [==============================] - 61s 9s/step - loss: 0.0019 - val_loss: 0.0131
# Epoch 7/30
# 7/7 [==============================] - 62s 9s/step - loss: 0.0013 - val_loss: 0.0129
# Epoch 8/30
# 7/7 [==============================] - 61s 9s/step - loss: 0.0012 - val_loss: 0.0123
# Epoch 9/30
# 7/7 [==============================] - 62s 9s/step - loss: 6.6347e-04 - val_loss: 0.0127
# Epoch 10/30
# 7/7 [==============================] - 61s 9s/step - loss: 5.7785e-04 - val_loss: 0.0128
# Epoch 11/30
# 7/7 [==============================] - 61s 9s/step - loss: 3.9413e-04 - val_loss: 0.0125
# Epoch 12/30
# 7/7 [==============================] - 65s 9s/step - loss: 2.9131e-04 - val_loss: 0.0125
# Epoch 13/30
# 7/7 [==============================] - 61s 9s/step - loss: 2.2808e-04 - val_loss: 0.0126
# Epoch 14/30
# 7/7 [==============================] - 62s 9s/step - loss: 1.8436e-04 - val_loss: 0.0124
# Epoch 15/30
# 7/7 [==============================] - 62s 10s/step - loss: 1.2825e-04 - val_loss: 0.0124
# Epoch 16/30
# 7/7 [==============================] - 66s 9s/step - loss: 1.4627e-04 - val_loss: 0.0124
# Epoch 17/30
# 7/7 [==============================] - 63s 9s/step - loss: 1.1609e-04 - val_loss: 0.0125
# Epoch 18/30
# 7/7 [==============================] - 62s 9s/step - loss: 9.4380e-05 - val_loss: 0.0125
# Epoch 19/30
# 7/7 [==============================] - 64s 9s/step - loss: 8.3699e-05 - val_loss: 0.0126
# Epoch 20/30
# 7/7 [==============================] - 64s 9s/step - loss: 7.3983e-05 - val_loss: 0.0127
# Epoch 21/30
# 7/7 [==============================] - 62s 9s/step - loss: 6.5442e-05 - val_loss: 0.0125
# Epoch 22/30
# 7/7 [==============================] - 61s 9s/step - loss: 5.8414e-05 - val_loss: 0.0127
# Epoch 23/30
# 7/7 [==============================] - 62s 9s/step - loss: 5.0881e-05 - val_loss: 0.0125
# Epoch 24/30
# 7/7 [==============================] - 65s 9s/step - loss: 5.4039e-05 - val_loss: 0.0126
# Epoch 25/30
# 7/7 [==============================] - 62s 9s/step - loss: 5.7022e-05 - val_loss: 0.0126
# Epoch 26/30
# 7/7 [==============================] - 63s 9s/step - loss: 4.0670e-05 - val_loss: 0.0129
# Epoch 27/30
# 7/7 [==============================] - 63s 9s/step - loss: 4.7090e-05 - val_loss: 0.0127
# Epoch 28/30
# 7/7 [==============================] - 63s 9s/step - loss: 4.3669e-05 - val_loss: 0.0125
# Epoch 29/30
# 7/7 [==============================] - 63s 9s/step - loss: 5.0923e-05 - val_loss: 0.0128
# Epoch 30/30
# 7/7 [==============================] - 66s 10s/step - loss: 4.9842e-05 - val_loss: 0.0128

# %%
model.evaluate_generator(validation_generator, steps=STEP_SIZE_VAL)
for idx, row in df.iloc[lucky_test_samples].iterrows():    
    img = cv2.resize(cv2.imread(row[0]) / 255.0, dsize=(WIDTH, HEIGHT))
    y_hat = model.predict(img.reshape(1, WIDTH, HEIGHT, 3)).reshape(-1) * WIDTH
    
    xt, yt = y_hat[0], y_hat[1]
    xb, yb = y_hat[2], y_hat[3]
    
    img = cv2.cvtColor(img.astype(np.float32), cv2.COLOR_BGR2RGB)
    image = cv2.rectangle(img, (xt, yt), (xb, yb), (0, 0, 255), 1)
    plt.imshow(image)
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model.save("model_save")
# Out:
# INFO:tensorflow:Assets written to: model_save\assets

# %%
from tensorflow import keras
model = keras.models.load_model('model_save')
img = cv2.resize(cv2.imread('test.jpeg')/255.0, dsize=(WIDTH, HEIGHT))
y_hat = model.predict(img.reshape(1, WIDTH, HEIGHT, 3)).reshape(-1) * WIDTH
    
xt, yt = y_hat[0], y_hat[1]
xb, yb = y_hat[2], y_hat[3]
    
img = cv2.cvtColor(img.astype(np.float32), cv2.COLOR_BGR2RGB)
image = cv2.rectangle(img, (xt, yt), (xb, yb), (0, 0, 255), 1)
plt.imshow(image)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
